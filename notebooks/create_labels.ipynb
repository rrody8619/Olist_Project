# %%
# %pip install pandas pyarrow fastparquet
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.2.1
# [notice] To update, run: C:\Users\tech\AppData\Local\Programs\Python\Python313\python.exe -m pip install --upgrade pip

# %%
import os
import pandas as pd

# %%
input_path = '../artifacts/ml_table.parquet'
df = pd.read_parquet(input_path)

# %%
df['order_delivered_customer_date'] = pd.to_datetime(df['order_delivered_customer_date'])
df['order_estimated_delivery_date'] = pd.to_datetime(df['order_estimated_delivery_date'])

# %%
df = df.dropna(subset=['order_delivered_customer_date']).copy()

# %%
df['is_late'] = (df['order_delivered_customer_date'] > df['order_estimated_delivery_date']).astype(int)

# %%
print(df['is_late'].value_counts(normalize=True) * 100)
# Out:
# is_late
# 0    91.887101
# 1     8.112899
# Name: proportion, dtype: float64

# %%
#output_path = '../artifacts/labeled_table.parquet'
#df.to_parquet(output_path, index=False)

# %%
os.makedirs('../data/processed', exist_ok=True)
output_path = '../data/processed/labeled_table.parquet'
df.to_parquet(output_path, index=False)

# %%
print(f"  Labeled Table : {output_path}")
# Out:
#   Labeled Table : ../artifacts/labeled_table.parquet
